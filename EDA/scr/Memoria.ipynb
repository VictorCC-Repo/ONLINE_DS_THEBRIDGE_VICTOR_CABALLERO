# %% [markdown]
# ***MEMORIA***
#
# Se han obtenido los datos de una compañia aérea que opera entre Islas Azores y Europa continental.
#
# En primer lugar vamos al script que se llama transformación de datos en el vamos a trabajar los datos limpiándolos y extrayendo aquellos que identifiquemos de valor para nuestro análisis.
#
# El primer objetivo será sacar datos para trataer de identificar cuales son las averías más repetitivas según ATA. ATA es un sistema de estandarización en el que se han identicado con un código las distintas partes
# que componen las partes de un avión.
#
# Se han borrado columnas, filas y datos no relevantes. Tratamiento de nulos, funciones, uso de la libreria pandas.
#
# En la primera tabla que trabajamos tenemos 6464 eventos con retraso, vamos a filtrar lo que realmente nos interesa.
# El campo de título o headline es un campo que se rellena por personal del turno, no hay una estructura determinada para desarrollar por lo que no es fiable.
# Esa columna por ahora no vamos a borrarla porque quizás más adelante podamos usarla para encontrar algún tipo de patron.
# Por ejemplo: averías relacionadas con aire acondicionado, puede ser pack, aire, calor en cabina, etc..

# %%
# Filtraremos por ATA. Es cierto que tenemos un cierto número de campos que son nulos.
'''
 0   ID         6464 non-null   int64 
 1   Occurred   6464 non-null   object
 2   At         6464 non-null   object
 3   Issuer     6464 non-null   int64 
 4   A/C        6464 non-null   object
 5   Station    5983 non-null   object
 6   Headline   6464 non-null   object
 7   Flight No  5296 non-null   object
 8   ATA        4524 non-null   object
 9   Advise     5495 non-null   object
'''
# Out:
# '\n 0   ID         6464 non-null   int64 \n 1   Occurred   6464 non-null   object\n 2   At         6464 non-null   object\n 3   Issuer     6464 non-null   int64 \n 4   A/C        6464 non-null   object\n 5   Station    5983 non-null   object\n 6   Headline   6464 non-null   object\n 7   Flight No  5296 non-null   object\n 8   ATA        4524 non-null   object\n 9   Advise     5495 non-null   object\n'

# %%
#Identificamos que porcentaje le corresponde de nulos a cada columna
'''
ID            0.000000
Occurred      0.000000
At            0.000000
Issuer        0.000000
A/C           0.000000
Station       7.441213
Headline      0.000000
Flight No    18.069307
ATA          30.012376
Advise       14.990718
dtype: float64
'''
# Out:
# '\nID            0.000000\nOccurred      0.000000\nAt            0.000000\nIssuer        0.000000\nA/C           0.000000\nStation       7.441213\nHeadline      0.000000\nFlight No    18.069307\nATA          30.012376\nAdvise       14.990718\ndtype: float64\n'

# %% [markdown]
# Tenemos un 30% de los datos de las ATA con NaN
#
# Como nos interesan las averías que causan mayor retraso a la hora de coger un vuelo vamos hacer una query que identifique que eventos son y sacar una tabla combinada de ambas.
#
# Pero antes tenemos que limpiar y tratar los datos de la tabla de minutos de retraso
#
# La columna fecha contiene dia, mes, año y la hora. Limpiamos y solo dejamos la fecha para que sea compatible con la anterior tabla a la hora de hacer la query
#
# Guardamos las nuevas tablas con la limpieza de datos que hemos hecho.
#
# Importamos sqlite3 y csv
#
# Como nos interesan las averías que causan mayor retraso a la hora de coger un vuelo vamos hacer una query que identifique que eventos son y sacar una tabla combinada de ambas.
#
# Creamos conector y base de datos.
#
# Creamos dos tablas con las campos que nos interesan de las tablas que habíamos guardado previamente. Identificamos e insertamos las filas en las de los csv que habíamos guardado en las nuevas tablas de sqlite3.
#
# Guardamos los cambios y creamos la tabla con los datos combinados de ambas tablas.
#
# Que será la tabla principal de donde sacaremos los datos sobre las averías.
#
# Guardamos y cerramos la conexión.

# %% [markdown]
# ***Análisis de datos***
#
# ***MAIN Impacto de las averías en tiempo de retraso y por aeropuerto***
#
# Hubo un punto que tenía tanta cantidad de datos y posibles caminos a seguir llegué a un punto que no sabía que mostrar y finalmente me decidí por primero analizar cuales son las averías más frecuentes.
#
# Cual es la evolución de las averías tras el covid con el aumento de las operaciones
#
# Empezamos trabajando la tabla que creamos de eventos_retrasos. Transformamos algunos datos de la tabla que no son legibles.
#
# Se calcula tiempo total de minutos de retraso de los 6464 eventos: 231.842
#
# Identificamos la cantidad de nulos por
#
#  0   ID        6464 non-null   int64
#  1   Occurred  6464 non-null   object
#  2   At        6464 non-null   object
#  3   AC        6464 non-null   object
#  4   Station   5983 non-null   object
#  5   Headline  6464 non-null   object
#  6   FlightNo  5296 non-null   object
#  7   ATA       4524 non-null   object
#  8   Minutos   6446 non-null   float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 454.6+ KB
#
# ID             0
# Occurred       0
# At             0
# AC             0
# Station      481
# Headline       0
# FlightNo    1168
# ATA         1940
# Minutos       18
# dtype: int64
#
# Se extrae los dos primeros caracteres de cada valor en la columna "ATA"
#
# Contamos las repeticiones de cada par de caracteres en la nueva columna
#
# Seleccionamos los 5 valores más frecuentes de ATA
#
# ATA Principal
# 25    448       Avería por Interiores
# 12    414       Avería por Servicing
# 05    365       Avería por Mantenimiento programado
# 24    255       Avería por Sistema eléctrico
# 52    248       Avería por Puertas
# Name: count, dtype: int64
#
# Se cálcula que las 5 averías más repetitivas representan el 38.24% del total
#
# Identificamos cuales son los 5 subcódigos más comunes en cada una de las ATA del top 5
#
# Se extrae las filas donde los dos primeros caracteres de 'ATA' pertenecen a los cinco más comunes
#
# Contamos las repeticiones completas de "ATA" dentro de estas filas
#
# Para cada uno de los top 5 ATA , hallar los 5 subcódigos más comunes y sus porcentajes
#
# Hemos creado un diccionario con los valores total y porcentajes de cada ATA
#
# Copiamos dataframe original para analizar el tiempo de retraso originado por cada ATA
#
# Ahora, seleccionamos todas las filas donde la columna ATA no tiene nulos
#
# Prepararmos los datos para el treemap
#
# Contaremos las repeticiones de cada par de caracteres en la columna "ATA Principal"
#
# Creamos el treemap para todas las "ATA Principal" values

# %% [markdown]
# ![Descripción de la imagen](Datos/Imagenes/rango_de_ata.png)

# %% [markdown]
# En el gráfico anterior podemos ver que predominan los ATA 05, 12, 25, 25 y 52.
#
# Los colores van desde el azul marino con los retrasos más frecuentes y con mayor frecuente hasta los amarilos con menor frecuencia.
#
# En total tenemos 52 ATA o 52 tipos de averías.
#
# Nos centraremos a continuación en el top 5 de averías.
#
# A continuación creamos un gráfico de barras con las 5 ATA más frecuentes.

# %% [markdown]
# ![Descripción de la imagen](Datos/Imagenes/top_5_ata_mas_frecuentes.png)

# %% [markdown]
# Podemos obervar la cantidad de retasos que tiene cada avería del top 5.TimeoutError
# ATA "25" interiores: 448 averías.
# ATA "12" servicing : 414 averías.
# ATA "05" mtto: 365 averías.
# ATA  "24" eléctricos: 255 averías.
# ATA "52" puertas: 248 averías.
# Top 5: 1730 averías.
# Total: 6464 averías.
#
# Identificar la cantidad total de los ATA más frecuentes por cada año desde 2021 hasta 2024
#
# Identificar el número de retrasos por cada ATA y cada año
#
# Year/ATA Principal	05	12	24	25	52
# 2021	57	53	64	81	72
# 2022	113	106	69	128	71
# 2023	100	108	82	145	76
# 2024	95	147	40	94	29
#
# Sumar los minutos de retraso por cada ATA y cada año
#
# Year/ATA Principal	05	12	24	25	52
# 2021	2934.0	768.0	3216.0	1263.0	1421.0
# 2022	6466.0	2733.0	4544.0	2356.0	2502.0
# 2023	6613.0	2798.0	5372.0	2554.0	1873.0
# 2024	4314.0	2917.0	2585.0	3139.0	829.0
#
# Ahora vamos a visualizar el total de minutos de retraso por ATA de menor a mayor
#
# Calculamos el número total de minutos de cada ATA, lo ordenamos y creamos una gráfica de barras horizontales

# %% [markdown]
# ![Descripción de la imagen](Datos/Imagenes/total_minutos_retraso_por_ata.png)

# %% [markdown]
# Seguimos en el análisis con el porcentaje que represtan el total de las averías principales frente al resto.
#
# Porcentaje de cada uno de los ATA principales y el resto, serie para los datos del gráfico circular
#
# Creamos el gráfico circular

# %% [markdown]
# ![Descripción de la imagen](Datos/Imagenes/porcentaje_ata_mas_frecuentes.png)

# %% [markdown]
# Análisis del Gráfico Circular
#
# El gráfico circular muestra la distribución de los principales códigos ATA en comparación con todos los demás ATA combinados, utilizando una variedad de colores desde azul claro hasta azul oscuro.
#
# Porcentajes de los ATA Principales y Otros:
# ATA 25: 9.90%
# ATA 12: 9.15%
# ATA 05: 8.07%
# ATA 24: 5.64%
# ATA 52: 5.48%
# Otros: 61.76%
#
# Conclusiones
#
# Dominancia de Otros ATA: Aunque los cinco ATA principales representan una porción significativa de los eventos,
# la categoría "Otros" constituye la mayoría, con el 61.76% del total.
#
# Esto indica que hay una gran diversidad de problemas que no están concentrados en los cinco ATA principales.
#
# Frecuencia de los Principales ATA: Los códigos ATA 25, 12, 05, 24, y 52 son los más recurrentes,
# pero cada uno de ellos individualmente representa menos del 10% del total de eventos.
#
# Diversidad de Problemas: La gran proporción de "Otros" sugiere que hay muchos tipos diferentes
# de problemas que ocurren con menor frecuencia, lo que podría requerir un enfoque más amplio
# en la gestión y solución de estos problemas.

# %% [markdown]
# Ahora vamos a enfocarnos un poco más detenidamente en cada ATA con un gráfico boxplot de cada una y al final una figura que albergue los 5 gráficos juntos en horizaontal
#
#
# ![Descripción de la imagen](Datos/Imagenes/box_plots_independienes_25.png)
#
# ATA 25:
# Distribución: La mediana del número de averías parece ser relativamente constante a lo largo de los años, pero con algunos valores extremos (outliers) notables en 2024.
# Variabilidad:
# 2021-2023: Relativamente baja, con cajas (IQR) más pequeñas y bigotes cortos, indicando que los datos están agrupados estrechamente alrededor de la mediana.
# 2024: Mayor variabilidad con algunos outliers significativos, lo que sugiere que hubo algunos años con un número de averías excepcionalmente alto.
# Tendencia General: La mediana del número de averías para ATA 25 se mantiene relativamente constante de 2021 a 2023, con una ligera disminución en 2024.
# Outliers: En 2024, se observa un aumento significativo de outliers, lo que indica un año con variaciones atípicas y más averías extremas.
#
# ![Descripción de la imagen](Datos/Imagenes/box_plots_independienes_12.png)
#
#
# ATA 12
# Distribución: La mediana del número de averías muestra cierta variabilidad en comparación al ATA 25, especialmente con valores extremos en 2022 y 2023.
# Variabilidad:
# 2021 y 2024: Baja variabilidad, con cajas y bigotes más cortos.
# 2022-2023: Mayor variabilidad, con presencia de varios outliers, indicando años con variaciones significativas en el número de averías.
# Tendencia General: La mediana de averías para ATA 12 muestra una variación más pronunciada, especialmente con un aumento en 2022 y 2023, seguido de una reducción en 2024.
# Outliers: Los outliers son más prominentes en 2022 y 2023, sugiriendo picos en el número de averías en estos años.
#
#
# ![Descripción de la imagen](Datos/Imagenes/box_plots_independienes_05.png)
#
# ATA 05:
# Distribución: La mediana del número de averías es bastante consistente, aunque hay algunos outliers notables.
# Variabilidad:
# 2021-2023: Moderada, con cajas relativamente uniformes pero con algunos outliers en 2022 y 2023.
# 2024: Baja variabilidad, con una caja más pequeña y menos dispersión.
# Tendencia General: La mediana del número de averías para ATA 05 es bastante consistente, aunque hay un ligero aumento en la variabilidad a lo largo de los años.
# Outliers: Hay algunos outliers significativos, especialmente en 2022 y 2023, indicando años con picos de averías.
#
#
# ![Descripción de la imagen](Datos/Imagenes/box_plots_independienes_24.png)
#
# ATA 24:
# Distribución: La mediana del número de averías muestra cierta consistencia, aunque hay variaciones en la distribución de los datos.
# Variabilidad:
# 2021 y 2024: Baja, con cajas y bigotes más cortos.
# 2022-2023: Mayor variabilidad, especialmente en 2022 con outliers significativos.
# Tendencia General: La mediana de averías para ATA 24 muestra consistencia, aunque hay fluctuaciones en la distribución de los datos.
# Outliers: 2022 y 2023 presentan outliers significativos, lo que sugiere años con variaciones atípicas.
#
#
# ![Descripción de la imagen](Datos/Imagenes/box_plots_independienes_52.png)
#
# ATA 52:
# Distribución: La mediana del número de averías muestra una tendencia a la baja, con valores extremos en algunos años.
# Variabilidad:
# 2021 y 2024: Baja, con cajas y bigotes más cortos.
# 2022-2023: Alta, con presencia de varios outliers, indicando años con variaciones significativas en el número de averías.
# Tendencia General: La mediana del número de averías para ATA 52 tiende a ser más baja en 2024 comparado con los años anteriores.
# Outliers: Los años 2022 y 2023 tienen varios outliers, indicando picos en el número de averías.
#
# ![Descripción de la imagen](Datos/Imagenes/figura_box_plots_horizontal.png)
#
# Conclusiones Generales:
# Consistencia: Algunas ATA muestran una mayor consistencia en el número de averías a lo largo de los años, como el ATA 25.
# Variabilidad: Otras ATA, como 12 y 52, muestran una mayor variabilidad, con varios años presentando outliers significativos.
# Outliers: La presencia de outliers en varios ATA sugiere que hubo años con un número de averías inusualmente alto, lo cual podría ser investigado más a fondo para entender las causas subyacentes.
# Tendencias: No se observa una tendencia clara ascendente o descendente en el número de averías para todos los ATA, pero la variabilidad y los outliers destacan ciertos años con eventos excepcionales.

# %% [markdown]
# Análisis bivariante
#
# Siguiendo con el análisis queremos identificar en que station o aeropuerto tendríamos mayor robabilidad de sufrir un retraso en nuestro vuelo y que cantidad corresponden en de las ATA principales en las bases con mayor retraso.
#
# Hacemos un gráfico de dispersión
#
# ![Descripción de la imagen](Datos/Imagenes/dispersion_estacion_ata.png)
#
# Podemos identificar que dos estaciones tienen un número mayor de eventos en una amplia variedad de ATA que el resto de estaciones.
# Esto podría ser un indicador de que estas estaciones tienen un mayor riesgo de que el vuelo que cojamos pueda sufrir retraso.
# Además hemos identificado que estas estaciones son las bases principales donde se realiza el mantenimiento de las aeronaves.
# También distinguimos que hay puntos más grandes o más oscuros en las bases principales

# %% [markdown]
# Nos centramos ahora con las estaciones
#
# Queremos mostrar las estaciones con mayor cantidad de retrasos
#
# Agrupamos, contamos los retrasos por estación y ordenamos por el número de retrasos en orden descendente
#
# Convertimos los datos a un DataFrame para su visualización
#
# Station	Counts
# 12	PDQ	2457
# 13	PIQ	1417
# 7	HOR	89
# 21	SMA	47
# 22	TER	32
# 2	CVU	25
# 4	FNC	24
# 8	MAD	16
# 3	FLW	13
# 6	GRW
#
# Gráfico por base con mayor cantidad ed retraso
#
# Será un gráfico de barras de las estaciones con más retrasos en horizontal
#
# Calcularemos el porcentaje de retrasos por estación y filtramos las estaciones principales
#
# ![Descripción de la imagen](Datos/Imagenes/top_estaciones_retrasos.png)
#
# Calculamos el porcentaje del resto de las estaciones
#
# Creamos un gráfico circular de las estaciones con más retrasos, para ello creamos una serie para los dos estaciones principales y el resto
#
# ![Descripción de la imagen](Datos/Imagenes/porcentaje_retraso_bases_reparaciones.png)
#
# Podemos ver que las estaciones con una mayor cantidad de retrasos son PDQ y PIQ en comparación al resto de bases.
#
# Es importante tener en cuenta que, en estos dos aeropuertos tenemos las bases principales de mantenimiento
#
# PDQ tiene el 58.9 % y  122.413 minutos.
# PIQ 33.99% y 56.048 minutos.
# El resto de aeropuertos hacen el 7.1% y 42.830 minutos

# %% [markdown]
# Cremoas un histograma de los valores de minutos.
# El objetivo es identificar cuando tiempo suelen durar más los retrasos por problemas técnicos.
#
# ![Descripción de la imagen](Datos/Imagenes/distribucion_retrasos.png)
#
# Creamos un gráfico de barras con los minutos de retraso por estación
#
# ![Descripción de la imagen](Datos/Imagenes/top_10_estaciones_minutos_retraso.png)
#
#    Station   Minutos
# 14     PDQ  122413.0
# 15     PIQ   56048.0
# 8      HOR   11249.0
# 23     SMA    5771.0
# 24     TER    4531.0
# 5      FNC    2622.0
# 2      CVU    2419.0
# 17     PNA    1834.0
# 16     PMI    1719.0
# 1      AVR    1691.0
#
# Calculamos el tiempo medio de minutos de retraso por estación y ordenamos en descendente
#
# Station	Minutos
# 25	TLS	748.000000
# 17	PNA	611.333333
# 22	SID	583.000000
# 33	ZAZ	382.000000
# 1	AVR	241.571429
# 21	SDR	206.333333
# 20	RMU	197.750000
# 16	PMI	191.000000
# 29	VGO	150.000000
# 0	AGA	147.500000
# 19	RAK	137.000000
# 18	PXO	104.500000
# 8	HOR	87.201550
# 5	FNC	84.580645
# 23	SMA	81.281690
# 24	TER	78.120690
# 11	MRS	72.500000
# 2	CVU	67.194444
# 13	OVD	62.833333
# 7	GRW	57.083333
# 4	FLW	53.100000
# 6	GLN	53.000000
# 28	VCE	50.000000
# 10	MAD	40.545455
# 14	PDQ	35.574833
# 15	PIQ	26.946154
# 32	XRY	26.666667
# 9	LIL	24.000000
# 31	VLL	16.000000
# 3	EAS	12.000000
# 26	TNG	10.000000
# 12	NKC	5.000000
# 30	VIT	3.000000
# 27	TRN	0.000000
#
# Calculamos el tiempo medio de minutos de retraso por estación, filtramos las estaciones de interés (las 5 primeras y PDQ y PIQ). conncatenamos las estaciones de interés en un solo DataFrame
#
# Creamos el gráfico de barras horizontales
#
# ![Descripción de la imagen](Datos/Imagenes/estaciones_retraso_horizontal.png)
#
# PDQ y PIQ a pesar de ser las estaciones mayor cantidad de número de retrasos son de los que se solventan en menor tiempo.
#
# Boxplot de Minutos por ATA
#
# ![Descripción de la imagen](Datos/Imagenes/boxplots_minutos_ata.png)
#
# El boxplot de los minutos de retraso por cada ATA principal proporciona varias conclusiones importantes sobre la distribución de los tiempos de retraso asociados con cada código ATA principal:
#
# Mediana de Retraso:
#
# La línea dentro de cada caja representa la mediana (percentil 50) de los minutos de retraso para cada código ATA. Esto da una idea del retraso típico para cada código.
# Rango Intercuartílico (IQR):
#
# La caja abarca desde el primer cuartil (percentil 25) hasta el tercer cuartil (percentil 75). Esto muestra la dispersión central de los datos y dónde se concentra el 50% de los retrasos.
# Códigos ATA con cajas más grandes tienen una mayor variabilidad en sus retrasos.
# Valores Atípicos:
#
# Los puntos fuera de los "bigotes" del boxplot se consideran valores atípicos. Estos puntos indican retrasos que son significativamente diferentes del resto de los datos.
# Algunos códigos ATA tienen más valores atípicos, lo que sugiere que pueden estar asociados con eventos de retraso extremos.
# Bigotes:
#
# Los bigotes se extienden hasta 1.5 veces el IQR desde los cuartiles. Esto incluye la mayoría de los datos y ayuda a identificar la extensión general de los retrasos.
# Conclusiones Específicas:
# Código ATA 05:
#
# Parece tener una mediana relativamente baja comparada con otros códigos, indicando retrasos menores típicamente.
# Tiene una caja más compacta, sugiriendo menos variabilidad en los retrasos.
# Código ATA 12:
#
# Presenta una mediana más alta que 05 y una caja más grande, indicando más variabilidad.
# También muestra varios valores atípicos, lo que indica que puede tener algunos retrasos extremos.
# Código ATA 25 y 52:
#
# Tienen medianas y rangos intercuartílicos intermedios. Sin embargo, 52 parece tener menos valores atípicos comparado con 25.
# Código ATA 24:
#
# Muestra una mediana más baja pero tiene una mayor dispersión en la parte superior, indicando que aunque los retrasos típicos son menores, puede haber eventos de retraso más significativos ocasionalmente.
# Implicaciones Prácticas:
# Gestión de Mantenimiento:
#
# Los códigos ATA con medianas más altas y mayores IQRs pueden necesitar una atención más cuidadosa y proactiva para reducir los tiempos de retraso.
# Planificación Operacional:
#
# Los valores atípicos significativos deben ser analizados más a fondo para entender y mitigar las causas de estos retrasos extremos.
# Políticas de Intervención:
#
# Códigos ATA con menos variabilidad (como 05) pueden estar bien gestionados, pero aún se deben revisar los procedimientos para los códigos con más valores atípicos para mejorar la consistencia.
# Este análisis inicial del boxplot proporciona una visión clara de dónde se concentran los retrasos y qué áreas podrían necesitar atención adicional para mejorar la puntualidad de las operaciones.
#
#
# Outliers:
#
# ATA 05 - Tareas de mantenimiento programados.
# Observaciones:
# Los valores atípicos de este grupo muestran que aunque la mayoría de los retrasos son menores, hay algunos eventos que causan retrasos significativos.
# Los outliers pueden representar fallas graves o eventos inusuales que requieren más tiempo planeado para una reparación.
# ATA 12 - Servicing - Necesidad de recargas los sistemas de líquidos, gases o elementos de desgaste como ruedas o frenos. Pueden ser en mantenimientos programados o no.
# Observaciones:
# Este grupo presenta una cantidad notable de outliers, indicando que además de los retrasos típicos, hay varios eventos extremos.
# Estos outliers pueden ser causados por problemas complejos o recurrentes que no se resuelven fácilmente.
# ATA 25 - Defectos en interiores del avión
# Observaciones:
# Tiene varios outliers, lo que sugiere que aunque la mayoría de los retrasos son manejables, hay incidentes ocasionales que causan grandes retrasos.
# Podría ser útil investigar estos casos para identificar patrones comunes o causas subyacentes.
# ATA 24 - Eléctricos
# Observaciones:
# Este grupo tiene una dispersión significativa de outliers hacia los retrasos más largos, lo que puede indicar problemas intermitentes pero severos.
# Estos eventos extremos podrían estar relacionados con fallas críticas que afectan significativamente la operación.
# ATA 52 - Puertas
# Observaciones:
# Similar a 25, este grupo tiene outliers que representan retrasos mucho mayores que la mediana.
# Los outliers aquí pueden indicar fallas técnicas específicas que causan estos retrasos extendidos.
# '''
#
# Vamos a profundar algo más en los outliers del top 5 de ATA
#
# Outliers usando IQR para identificarlos, filtramos los 5 ATAs con la mayor cantidad de outliers, y agrupamos outliers por 'ATA Principal' de los top 5
#
#
# ATA Principal		count	mean	std	min	25%	50%	75%	max
# 05	45.0	272.244444	254.701622	112.0	140.00	183.0	276.0	1481.0
# 21	33.0	176.454545	91.613690	106.0	120.00	140.0	187.0	524.0
# 24	50.0	161.440000	49.256579	106.0	123.25	139.0	201.5	296.0
# 27	37.0	196.216216	93.579774	106.0	144.00	164.0	225.0	581.0
# 61	29.0	245.862069	174.291776	117.0	151.00	189.0	241.0	799.0
#
#
# ATA 05: Tareas de mantenimiento programados.
# La gran desviación estándar y el valor máximo indican que hay varios eventos de retraso extremadamente largos, se pueden deben a inoperatividad por falta de repuestos.
#
# ATA - 21: Aire Acondicionado
# Aunque tiene menos outliers que 05, la media sigue siendo alta, indicando retrasos significativos.
#
# ATA - 24: Sistema eléctrico
# Este grupo tiene menos variabilidad en los retrasos extremos, pero aún representa un problema notable.
#
# ATA - 27: Control de vuelo
# Los retrasos son comparables a los de 21 y 61, con eventos que pueden ser muy prolongados.
#
# ATA - 61: Hélices
# La alta desviación estándar y el valor máximo indican retrasos muy variables y algunos extremadamente largos.
#
# Posibles mejoras:
# Revisar y mejorar los procedimientos de mantenimiento y reparación para minimizar los retrasos asociados con estos ATAs.
# Implementar un sistema de monitorización continua para estos ATAs

# %% [markdown]
# ***AnálisIs de datos***
#
# ***MAIN Histórico de vuelos vs vuelos con retraso***
#
# Histórico vuelos compañía
#
# Ejecutamos csv histórico vuelos y modificamos fechas a datetime de pandas
#
# Identificamos el porcentaje de nulos
# echa                         0.000000
# Numero vuelo                  0.000000
# Aeropuerto Despegue Real      0.000000
# Aeropuerto Aterrizaje Real    0.000000
# Matricula Real                0.429021
# Flota Real                    0.000000
# historic.isna().mean()*100
# #El porcentaje de nulos es asumible solo un 0,42%
#
# Ahora ejecutamos csv eventos_retrasos.
#
# El objetivo es saber el número de vuelos totales y compararlos con el número de vuelos afectados por retrasos técnicos.
# Hallar porcentajes y bases más afectadas.
#
# Hacemos el mismo proceso para convertir los datos a pandas
#
# Creamos una función para segmentar los avión por tipo de flota y vuelos de corta y media distancia.
#
# Es necesario transformar datos de las matrículas ya que no coinciden.
#
# Creamos diccionario para mapear AC a Flota y añadimos la columna Flota a eventos_retrasos
#
# Se filtra filas con fecha Occurred mayor a 2023-09-30, ya que en la tabla historico de vuelos solo tenemos datos hasta esa fecha a diferencia de la otra tabla y nos asegurarnos de que las fechas estén en el mismo formato.
#
# Se intenta combinar las tablas de diversas maneras pero no hay forma. Al crear la nueva tabla como tabla principal histórico haciendo un join a eventos retrasos, añadimos a la tabla dos columnas Retraso si ha tenido o no,
# y si ha tenido que se añade el tiempo a la nueva columna Minutos.
# Siempre da no y 0.
#
# Intentamos de otra manera extraer los datos.
#
# Analizamos los retrasos por año y el número de vuelos totales por año
#
# Añadimos una columna de año a ambos DF, número total de vuelos por año y número de vuelos con retrasos por año a la tabla eventos retrasos
#
# Combinamos ambos DataFrames en uno solo. Usamos merge para fusionar ambos DF, año es la clave y estarán las columnas de vuelos por año y se agregan si coinciden las de retrasos sino NaN.
# Con las condiciones de que aquellos en los que haya NaN los sustituimos por 0 para evitar discrepancias y aseguramos que sea entero.Número total de vuelos
# Y calculamos la proporción de vuelos con retrasos de los vuelos con retrasos respecto a los vuelos totales.
#
# Creamos una figura que contenga dos subplots:
#
# 1. Gráfica de barras del número de vuelos totales y con retrasos por año
#
# 2. Gráfica de barras de la proporción de vuelos con retrasos por año

# %% [markdown]
# ![Descripción de la imagen](Datos/Imagenes/analisis_vuelos_retrasos_barras.png)

# %% [markdown]
# Se puede apreciar una ligera disminución de los vuelso con retrasos en el año 2023, en comparación al aumento del 2021 al 2022
# (Mostramos la tabla de datos_combinados)
#
# Ahora analizaremos el top de 6 aeropuerto cn mayor numero de retraso y el número de vuelos totales que tienen al año
#
# 1. Calcular las 6 estaciones con mayor cantidad de vuelos con retraso por año
#
#
# 2.  Calcular el número total de vuelos en las estaciones top 6 por año
#
#
# 3. Combinar los datos para obtener la proporción de retrasos
#
# 4. Crear las gráficas con dos subplots
#
# Gráfica de las 6 estaciones con mayor cantidad de vuelos con retraso por año
#
# Gráfica de la proporción de vuelos con retraso en las top 6 estaciones por año
#
#  Mostrar los datos combinados para verificación
#
# Top 6 Aeropuertos con Mayor Cantidad de Vuelos con Retraso por Año: Esta gráfica de barras muestra los 6 aeropuertos con mayor cantidad de vuelos con retraso por cada año.
#
# Proporción de Vuelos con Retraso en Top 6 Aeropuertos por Año: Esta gráfica de barras muestra la proporción de vuelos con retraso en los 6 aeropuertos seleccionados, por cada año.
#
# ![Descripción de la imagen](Datos/Imagenes/analisis_top6_estaciones_retrasos.png)
#
#
#
#
# Análisis comentado de cada  gráfico
#
# 1. Top 6 Aeropuertos con Mayor Cantidad de Vuelos con Retraso por Año
# Descripción:
# La primera gráfica de barras muestra los 6 aeropuertos con la mayor cantidad de vuelos con retraso para cada año.
# Cada aeropuerto está representado con un color distinto, la altura es el numero de retrasos por año.
#
# Análisis:
#
# En 2021, los aeropuertos PDQ y PIQ destacan con un número significativo de vuelos con retraso (444 y 289, respectivamente). Hay que destacar que son las bases principales de reparaciones.
# En 2022, el aeropuerto PDQ sigue liderando en retrasos con un aumento notable (962 vuelos con retraso), seguido por PIQ con 596 vuelos.
# En 2023, aunque los números generales de retrasos han disminuido, PDQ y PIQ siguen siendo los aeropuertos más afectados, con PDQ registrando 812 vuelos con retraso.
#
# Conclusiones:
#
# Los aeropuertos PDQ y PIQ tienen la mayor cantidad de vuelos con retraso año tras año.
#
# 2.  Proporción de Vuelos con Retraso en Top 6 Aeropuertos por Año
# Descripción:
# Esta gráfica de barras muestra la proporción de vuelos con retraso respecto al total de vuelos para los 6 aeropuertos con más retrasos por cada año. Las barras representan la proporción de vuelos con retraso.
#
# Análisis:
#
# En 2021, el aeropuerto PDQ tiene una proporción de retrasos de aproximadamente 2.5%, mientras que PIQ tiene cerca del 1.8%.
# En 2022, las proporciones aumentan, con PDQ alcanzando un 4.9% y PIQ un 3.3%.
# En 2023, aunque las proporciones disminuyen levemente, PDQ sigue teniendo una proporción alta de vuelos con retraso (4.6%).
# Conclusiones:
#
# La proporción de retrasos en los aeropuertos PDQ y PIQ es alta, indicando un problema persistente en estos aeropuertos.
#
# CONCLUSIONES Y RECOMENDACIONES FINALES
#
# Realizar un análisis más profundo en PDQ y PIQ para identificar las causas principales de los retrasos.
# Esto puede incluir factores como congestión del tráfico aéreo, condiciones climáticas, y eficiencia de los equipos de tierra.
#
# Proponer e implementar soluciones específicas para reducir los retrasos, como mejoras en la infraestructura, optimización de los horarios y cambios de turno del personal, priorizar trabajos en aquellos aviones que tengan los vuelos más próximos.
#
# Monitoreo continuo tanto de las ATA con mayor frencuencia de retraso como del resto a pesar de tener una menor frecuencia. Evaluar el impacto de las medidas implementadas y ajustar estrategias según sea necesario.
#
# Conclusión
# Este análisis EDA ha revelado patrones claros de retrasos en vuelos en aeropuertos específicos. Los aeropuertos PDQ y PIQ destacan por su alta incidencia y proporción de retrasos,
# no obstante no hay que olvidar que no son los aeropuerto con promedio de mayor duración.
# '''

# %% [markdown]
# Conclusiones finales
#
# 1. Retrasos por Tipo de Avería (ATA):
# ATA 25, 12 y 05 son las principales causas de retraso seguidas de ATA 24 y 52, representando una gran parte del total de eventos con retraso.
# No obstante, cada uno representa menos del 10% del total de retrasos.
#
# 2. Retrasos por año y tipo de avería:
# Hay bastante variabilidad en los retrasos por año para cada ATA, con algunos años mostrando retrasos más consistentes y otros con mucha dispersión.
# Los valores atípicos u outliers indican problemas o eventos inusuales que causaron grandes retrasos en ciertos años.
#
# 3. Estaciones con más retrasos:
# Hay 2 estaciones que tienen un número muy alto de eventos con retraso, lo que sugiere que es más probable que se sufran retrasos en estas ubicaciones.
# Cabe destacar que, estas 2 estaciones son bases de mantenimiento clave, lo que sugiere que los retrasos pueden estar relacionados con el mantenimiento programado o podría donde se anoten averías que se puedan diferir durante la operativa para una vez el avión tenga una escala se valore la avería con el personal técnico.
#
# 4. Minutos de retraso por estación:
# Analizando el tiempo medio de retraso por estación, identificamos las estaciones con más problemas de retraso.
# Las estaciones PDQ y PIQ también necesitan atención, ya que tienen tiempos de retraso significativos debido al gran número de eventos que se suceden.
#
# 5. Distribución de los minutos de retraso:
# La mayoría de los retrasos son cortos, lo que indica que muchos problemas técnicos se resuelven rápido, en menos de 25 minutos.
# Sin embargo, hay algunos retrasos largos que, aunque menos comunes o también llamados outliers, representan problemas serios que requieren más tiempo para solucionarse.
#
# 6. Total de minutos de retraso por ATA:
# Sumando los minutos de retraso por cada ATA a lo largo de los años, se ve que ciertos ATAs tienen un impacto mucho mayor.
# Esto es crucial para identificar las áreas que necesitan más atención.
#
# Posibles mejoras:
#
# 1. Reforzar las estaciones críticas:
# Las estaciones con más retrasos deben ser el foco de mejoras operativas y de mantenimiento para reducir el impacto en la puntualidad de los vuelos.
#
# 2. Optimización del Mantenimiento:
# Mejorar los procesos de mantenimiento en las estaciones principales podría reducir significativamente el número de retrasos.
#
# 3. Análisis de retrasos más extremos u outliers:
# Investigar los valores atípicos para identificar las causas específicas de los grandes retrasos. Con la finalidad de tomar medidas para prevenir futuros eventos similares.
#
# 4. Priorización de los ATAs con mayor impacto:
# Enfocar recursos en los ATAs que representan el mayor tiempo acumulado de retraso para implementar soluciones más efectivas.
#
# 5. Monitoreo Continuo y Mejora:
# Establecer un sistema de monitoreo continuo para todos los códigos ATA, no solo los principales, para identificar y mitigar problemas emergentes rápidamente.
