# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## PRACTICA OBLIGATORIA: VISUALIZACION BASICA

# %% [markdown]
# * La práctica obligatoria de esta unidad consiste en un único ejercicio de construcción de gráficas. Descarga este notebook en tu ordenador y trabaja en local. Ten en cuenta que tendrás que descar los directorios de imágenes y datos adicionales, si los hubiera.
# * Recuerda que debes subirla a tu repositorio personal antes de la sesión en vivo para que puntúe adecuadamente.
# * Recuerda también que no es necesario que esté perfecta, sólo es necesario que se vea el esfuerzo.
# * Esta práctica se resolverá en la sesión en vivo correspondiente y la solución se publicará en el repo del curso.

# %% [markdown]
# ### Ejercicio 0

# %% [markdown]
# Importa los paquetes y módulos que necesites a lo largo del notebook.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## #1

# %% [markdown]
# ### #1.1

# %% [markdown]
# Carga el dataset de casas de California que está en la ruta "./data/california_cities.csv". Muestra parte de su contenido y su descripción. Deshazte de las filas con nulos.

# %%
data = pd.read_csv("./data/california_cities.csv")
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 482 entries, 0 to 481
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          482 non-null    int64
#  1   city                482 non-null    object
#  2   latd                482 non-null    float64
#  3   longd               482 non-null    float64
#  4   elevation_m         434 non-null    float64
#  5   elevation_ft        470 non-null    float64
#  6   population_total    482 non-null    int64
#  7   area_total_sq_mi    480 non-null    float64
#  8   area_land_sq_mi     482 non-null    float64
#  9   area_water_sq_mi    481 non-null    float64
#  10  area_total_km2      477 non-null    float64
#  11  area_land_km2       478 non-null    float64
#  12  area_water_km2      478 non-null    float64
#  13  area_water_percent  477 non-null    float64
# dtypes: float64(11), int64(2), object(1)
# memory usage: 52.8+ KB
# None

# %%
data.describe()
# Out:
#        Unnamed: 0        latd       longd  elevation_m  elevation_ft  \
# count  482.000000  482.000000  482.000000   434.000000    470.000000
# mean   240.500000   36.095088 -119.837714   180.416705    567.168723
# std    139.285678    2.298006    2.147676   309.531825   1001.265722
# min      0.000000   32.578333 -124.263333   -34.000000   -180.000000
# 25%    120.250000   33.977292 -121.954931    22.000000     69.000000
# 50%    240.500000   36.204722 -119.708611    67.000000    200.000000
# 75%    360.750000   37.886667 -117.977292   173.500000    515.000000
# max    481.000000   41.965000 -114.596389  2402.000000   7880.000000
#
#        population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# count      4.820000e+02        480.000000       482.000000        481.000000
# mean       6.489493e+04         18.442183        16.840981          1.589630
# std        2.032041e+05         36.363230        32.694647          9.490386
# ...

# %%
data.dropna(inplace= True) #dropna elimina al menos todas las filas que tiene un valor nulo
data
# Out:
#      Unnamed: 0         city       latd       longd  elevation_m  \
# 0             0     Adelanto  34.576111 -117.432778        875.0
# 1             1  AgouraHills  34.153333 -118.761667        281.0
# 4             4     Alhambra  34.081944 -118.135000        150.0
# 5             5   AlisoViejo  33.575000 -117.725556        127.0
# 6             6      Alturas  41.487222 -120.542500       1332.0
# ..          ...          ...        ...         ...          ...
# 477         477   Yountville  38.403056 -122.362222         30.0
# 478         478        Yreka  41.726667 -122.637500        787.0
# 479         479     YubaCity  39.134722 -121.626111         18.0
# 480         480      Yucaipa  34.030278 -117.048611        798.0
# 481         481  YuccaValley  34.133333 -116.416667       1027.0
#
#      elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 0          2871.0             31765            56.027           56.009
# ...

# %% [markdown]
# ### #1.2
#
# Recrea la siguiente figura, para ello construye en apartados separados cada gráfico y luego haz un apartado en el que se junten los cuatro. Las figuras son:
# 1. Las ciudades más pobladas, con los numeros de las poblaciones (tendrás que usar texto y recordar que para centrarlos se necesita poner el argumento `ha` a "center"). (Colores: azul, gris, aceituna, marrón, con trasparencia)
# 2. Histograma del área total ocupada por las ciudades. (50 bins, fuente = "Bradley Hand itc", tamaño 18, color azul acero)
# 3. El scatter de área de agua de un ciudad con su poblacion.
# 4. El boxplot de la altura de las ciudades.

# %% [markdown]
# ![figura_ejempo.png](attachment:figura_ejempo.png)

# %%
ciudades_mas_pobladas = data["population_total"].sort_values(ascending= False)
ciudades_mas_pobladas
# Out:
# 239    3884307
# 367    1345895
# 359     466488
# 9       336000
# 386     324528
#         ...
# 366        334
# 190        219
# 7          185
# 448        112
# 327          1
# Name: population_total, Length: 427, dtype: int64

# %%
#las 5 ciudades más pobladas
top_ciudades = ciudades_mas_pobladas.head(5)
top_ciudades
# Out:
# 239    3884307
# 367    1345895
# 359     466488
# 9       336000
# 386     324528
# Name: population_total, dtype: int64

# %%
#intento fallido
'''
plt.figure(figsize=(10, 6))
plt.bar(top_ciudades["city"], top_ciudades["population_total"])
plt.xlabel('Ciudad')
plt.ylabel('Población')
plt.title('5 Ciudades más pobladas')
plt.xticks(rotation=45)  # Rotar las etiquetas del eje x para mejor visualización
plt.show()
'''
# Out:
# '\nplt.figure(figsize=(10, 6))\nplt.bar(top_ciudades["city"], top_ciudades["population_total"])\nplt.xlabel(\'Ciudad\')\nplt.ylabel(\'Población\')\nplt.title(\'5 Ciudades más pobladas\')\nplt.xticks(rotation=45)  # Rotar las etiquetas del eje x para mejor visualización\nplt.show()\n'

# %%
#creo un nuevo dataframe con los valores de dos columnas para realizar el gráfico
top_5_ciudades = data[["city", "population_total"]]

top_5_ciudades = top_5_ciudades.sort_values("population_total", ascending = False)
top_5_ciudades
# Out:
#            city  population_total
# 239  LosAngeles           3884307
# 367    SanDiego           1345895
# 359  Sacramento            466488
# 9       Anaheim            336000
# 386    SantaAna            324528
# ..          ...               ...
# 366    SandCity               334
# 190    Industry               219
# 7    AmadorCity               185
# 448      Vernon               112
# 327      Pomona                 1
#
# [427 rows x 2 columns]

# %%
#Nueva variable para los 5 primeros
top_5 = top_5_ciudades.head(5)

colors = ["blue", "gray","red","olive","brown"]

plt.figure()
#plt.bar(top_5["city"], top_5["population_total"], (color = for n in range(len(colors))), alpha = 0.3)
plt.bar(top_5["city"], top_5["population_total"], color = colors, alpha = 0.3, label = "ciudades_mas_pobladas") #después probé y he visto que no hacía falta un for...vaya forma de complicarme la vida
#plt.ylim (0, 5000) #Si pongo eso me salen todas las barras hasta 5000
plt.ylabel("Habitantes")
plt.xlabel("Ciudades")
plt.title("ciudades más pobladas de California")
plt.show()

# %%
plt.hist(data["area_total_km2"],bins = 50, color = "steelblue", label = "Hist Area más poblada")
plt.ylabel("Número de ciudades", fontdict = dict(family= "Bradley Hand itc", size = 18))
plt.xlabel("Superficie km^2", fontdict = dict(family= "Bradley Hand itc", size = 18))
plt.legend(title = "Hist Area más poblada")
plt.show()

# %%
area = data["population_total"]


plt.scatter(data["area_water_km2"], data["population_total"], color = "green", s = area, alpha = 0.7)
plt.xlabel("Area de agua en la ciudad (km^2)")
plt.ylabel("Población (miles habitantes)")
plt.ylim([0,4000])
plt.xlim([0,150])
plt.show()

#he intentado hacer lo de abajo de varias maneras y no doy con ello
'''
mayor_poblacion = pd.Series(data["population_total"], index= data["population_total"]).idxmax()
mayor_area_agua = pd.Series(data["population_total"], index= data["population_total"]).max()
props_flecha = {
    "arrowstyle": "<->", # este es una doble flecha uniendo el punto y el texto. Si solo un -> hara una flecha del texto al punto
    "connectionstyle" : "angle3" #esto permite la conexión de las flechas
}

plt.annotate("valor máximo", (mayor_poblacion, mayor_area_agua), xytext = (mayor_poblacion, 0.5), arrowprops= props_flecha)
'''
# Out:
# '\nmayor_poblacion = pd.Series(data["population_total"], index= data["population_total"]).idxmax()\nmayor_area_agua = pd.Series(data["population_total"], index= data["population_total"]).max()\nprops_flecha = {\n    "arrowstyle": "<->", # este es una doble flecha uniendo el punto y el texto. Si solo un -> hara una flecha del texto al punto\n    "connectionstyle" : "angle3" #esto permite la conexión de las flechas\n}\n\nplt.annotate("valor máximo", (mayor_poblacion, mayor_area_agua), xytext = (mayor_poblacion, 0.5), arrowprops= props_flecha)\n'

# %%
plt.boxplot(data["elevation_m"],vert = False, whiskerprops=dict(color='black'), boxprops = dict(facecolor = "red"),medianprops = dict(color= "black"),patch_artist= True, capprops=dict(color='black'))
plt.xlabel("Altitud (m)")
plt.title("Diagrama de caja de la Altitud de las ciudades de California")
#me di cuenta al hacer la figura con los axes que no hacía falta y dejaba de salir el error, aunque me salía el grádico plt.yticks("1")
# Out:
# Text(0.5, 1.0, 'Diagrama de caja de la Altitud de las ciudades de California')

# %% [markdown]
# ### #1.3
#
# Graba la figura en un archivo y sube el archivo a tu repo personal también.

# %%
fig = plt.figure()
fig, axs = plt.subplots(2,2, figsize = (15,15))
#gráfica 1
ax_1 = axs[0][0]
top_5 = top_5_ciudades.head(5)
colors = ["blue", "gray","red","olive","brown"]

#plt.bar(top_5["city"], top_5["population_total"], (color = for n in range(len(colors))), alpha = 0.3)
ax_1.bar(top_5["city"], top_5["population_total"], color = colors, alpha = 0.3, label = "ciudades_mas_pobladas") #después probé y he visto que no hacía falta un for...vaya forma de complicarme la vida
#plt.ylim (0, 5000) #Si pongo eso me salen todas las barras hasta 5000
ax_1.set_ylabel("Habitantes")
ax_1.set_xlabel("Ciudades")
ax_1.set_title("ciudades más pobladas de California")


#gráfica 2
ax_2 = axs[0][1]
ax_2.hist(data["area_total_km2"],bins = 50, color = "steelblue", label = "Hist Area más poblada")
ax_2.set_ylabel("Número de ciudades", fontdict = dict(family= "Bradley Hand itc", size = 18))
ax_2.set_xlabel("Superficie km^2", fontdict = dict(family= "Bradley Hand itc", size = 18))
ax_2.legend(title = "Hist Area más poblada")

#gráfica 3
area = data["population_total"]
ax_3 = axs[1][0]
ax_3.scatter(data["area_water_km2"], data["population_total"], color = "green", s = area, alpha = 0.7)
ax_3.set_xlabel("Area de agua en la ciudad (km^2)")
ax_3.set_ylabel("Población (miles habitantes)")
ax_3.set_ylim([0,4000])
ax_3.set_xlim([0,150])

#gráfica 4
ax_4 = axs[1][1]
ax_4.boxplot(data["elevation_m"],vert = False, whiskerprops=dict(color='black'), boxprops = dict(facecolor = "red"),medianprops = dict(color= "black"),patch_artist= True, capprops=dict(color='black'))
ax_4.set_xlabel("Altitud (m)")
ax_4.set_title("Diagrama de caja de la Altitud de las ciudades de California");
#me acabo de dar cuenta que no hacia falta ax_4.set_yticks["1"]...

# %%
fig.savefig("imagen_practica_obligatoria_unidad_1_sprint_8")
